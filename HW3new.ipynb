# %%
# Shivani Rathore
#The listed variables stores the sentences for POS Tagging, Dependeny and consituency 
sentence1='The average person squanders about forty days a year compensating for things he or she has forgotten.'
sentence2='It was simply a matter of learning to “think in more memorable ways” using the “extraordinarily simple” 2,500-year-old mnemonic technique known as the “memory palace” that Simonides of Ceos had supposedly invented in the rubble of the great banquet hall collapse.'
sentence3='A trained memory was not just a handy tool, but a fundamental facet of any worldly mind.'
sentence4='What we have been doing over the last century is defining memory incorrectly, understanding it incompletely, applying it inappropriately, and condemning it because it doesn’t work and isn’t enjoyable.'
sentence5='In a sense, the elaborate system of externalized memory we’ve created is a way of fending off mortality.'

# %%
import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)
warnings.filterwarnings('ignore')

# %%
#importing the required variables for the assignment 
import pandas as pd
import spacy
import os
from nltk.parse.stanford import StanfordDependencyParser
nlp = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fl/563c3f891_g731vrxpvjc5mc0000gn/T/ipykernel_21616/3524554446.py in <module>
#       4 import os
#       5 from nltk.parse.stanford import StanfordDependencyParser
# ----> 6 nlp = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)
#
# TypeError: load() got an unexpected keyword argument 'parse'

# %%
sentence_nlp=nlp(sentence1)
spacy_pos_tagged=[(word,word.tag_,word.pos_)for word in sentence_nlp]
print("POS Tag for Statement 1")
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T

# %%
sentence_nlp=nlp(sentence2)
spacy_pos_tagged=[(word,word.tag_,word.pos_)for word in sentence_nlp]
print("POS Tag for Statement 2")
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T

# %%
sentence_nlp=nlp(sentence3)
spacy_pos_tagged=[(word,word.tag_,word.pos_)for word in sentence_nlp]
print("POS Tag for Statement 3")
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T

# %%
sentence_nlp=nlp(sentence4)
spacy_pos_tagged=[(word,word.tag_,word.pos_)for word in sentence_nlp]
print("POS Tag for Statement 4")
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T

# %%
sentence_nlp=nlp(sentence5)
spacy_pos_tagged=[(word,word.tag_,word.pos_)for word in sentence_nlp]
print("POS Tag for Statement 5")
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T

# %%
import os
from nltk.parse.stanford import StanfordDependencyParser
java_path = r'C:\Program Files\Java\jdk-15\bin\java.exe'
os.environ['JAVAHOME'] = java_path
sdp = StanfordDependencyParser(path_to_jar='D:\Fall 2021\Python\stanford-parser-4.0.0\stanford-parser.jar',
                               path_to_models_jar='D:\Fall 2021\Python\stanford-parser-4.0.0\stanford-parser-4.0.0-models.jar')

# %%
result1 = list(sdp.raw_parse(sentence1))[0]
print("Dependency for Statement 1")
result1

# %%
result2 = list(sdp.raw_parse(sentence2))[0]
print("Dependency for Statement 2")
result2

# %%
result3 = list(sdp.raw_parse(sentence3))[0]
print("Dependency for Statement 3")
result3

# %%
result4 = list(sdp.raw_parse(sentence4))[0]
print("Dependency for Statement 4")
result4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fl/563c3f891_g731vrxpvjc5mc0000gn/T/ipykernel_21616/1979095753.py in <module>
# ----> 1 result4 = list(sdp.raw_parse(sentence4))[0]
#       2 print("Dependency for Statement 4")
#       3 result4
#
# NameError: name 'sdp' is not defined

# %%
result5 = list(sdp.raw_parse(sentence5))[0]
print("Dependency for Statement 5")
result5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fl/563c3f891_g731vrxpvjc5mc0000gn/T/ipykernel_21616/1392835169.py in <module>
# ----> 1 result5 = list(sdp.raw_parse(sentence5))[0]
#       2 print("Dependency for Statement 5")
#       3 result5
#
# NameError: name 'sdp' is not defined

# %%
# Constituency Prasers
import os
java_path = r'C:\Program Files\Java\jdk-15\bin\java.exe'
os.environ['JAVAHOME'] = java_path
from nltk.parse.stanford import StanfordParser
scp = StanfordParser(path_to_jar='D:\Fall 2020\Python\stanford-parser-4.0.0\stanford-parser.jar',
                     path_to_models_jar='D:\Fall 2020\Python\stanford-parser-4.0.0\stanford-parser-4.0.0-models.jar')

# %%
result1 = list(scp.raw_parse(sentence1))[0]
print("constituency for Statement 1")
result1
# Out:
# constituency for Statement 1
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('DT', ['The']), Tree('JJ', ['average']), Tree('NN', ['person'])]), Tree('VP', [Tree('VBZ', ['squanders']), Tree('NP', [Tree('QP', [Tree('RB', ['about']), Tree('CD', ['forty'])]), Tree('NNS', ['days'])]), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['year'])]), Tree('S', [Tree('VP', [Tree('VBG', ['compensating']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('NNS', ['things'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['he']), Tree('CC', ['or']), Tree('PRP', ['she'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['forgotten'])])])])])])])])])]), Tree('.', ['.'])])])

# %%
result2 = list(scp.raw_parse(sentence2))[0]
print("constituency for Statement 2")
result2
# Out:
# constituency for Statement 2
# ...

# %%
result3 = list(scp.raw_parse(sentence3))[0]
print("constituency for Statement 3")
result3
# Out:
# constituency for Statement 3
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('DT', ['A']), Tree('VBN', ['trained']), Tree('NN', ['memory'])]), Tree('VP', [Tree('VBD', ['was']), Tree('NP', [Tree('CONJP', [Tree('RB', ['not']), Tree('RB', ['just'])]), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['handy']), Tree('NN', ['tool'])]), Tree(',', [',']), Tree('CC', ['but']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['fundamental']), Tree('NN', ['facet'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['any']), Tree('JJ', ['worldly']), Tree('NN', ['mind'])])])])])]), Tree('.', ['.'])])])

# %%
result4 = list(scp.raw_parse(sentence4))[0]
print("constituency for Statement 4")
result4
# Out:
# constituency for Statement 4
# ...

# %%
result5 = list(scp.raw_parse(sentence5))[0]
print("constituency for Statement 5")
result5
# Out:
# constituency for Statement 5
# Tree('ROOT', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['sense'])])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['elaborate']), Tree('NN', ['system'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('JJ', ['externalized']), Tree('NN', ['memory'])]), Tree('SBAR', [Tree('S', [Tree('NP', [Tree('PRP', ['we'])]), Tree('VP', [Tree('VBP', ['’ve']), Tree('VP', [Tree('VBN', ['created'])])])])])])])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['way'])]), Tree('PP', [Tree('IN', ['of']), Tree('S', [Tree('VP', [Tree('VBG', ['fending']), Tree('PRT', [Tree('RP', ['off'])]), Tree('NP', [Tree('NN', ['mortality'])])])])])])]), Tree('.', ['.'])])])
